# %%
# pip install googletrans==4.0.0-rc1

# %%
# import googletrans
import pandas as pd

# %%
# translator = googletrans.Translator()

# %%
# csv파일 읽어오기
# q1 = pd.read_csv("/content/q1.csv", encoding = "utf-8")
# q2 = pd.read_csv("/content/q2.csv", encoding = "utf-8")
# q3 = pd.read_csv("/content/q3.csv", encoding = "utf-8")
# q4 = pd.read_csv("/content/q4.csv", encoding = "utf-8")
# q5 = pd.read_csv("/content/q5.csv", encoding = "utf-8")
# q6 = pd.read_csv("/content/q6.csv", encoding = "utf-8")
# q7 = pd.read_csv("/content/q7.csv", encoding = "utf-8")
# q8 = pd.read_csv("/content/q8.csv", encoding = "utf-8")
# q9 = pd.read_csv("/content/q9.csv", encoding = "utf-8")
# q10 = pd.read_csv("/content/q10.csv", encoding = "utf-8")
# q11 = pd.read_csv("/content/q11.csv", encoding = "utf-8")
# q12 = pd.read_csv("/content/q12.csv", encoding = "utf-8")
# q13 = pd.read_csv("/content/q13.csv", encoding = "utf-8")
# q14 = pd.read_csv("/content/q14.csv", encoding = "utf-8")
# q15 = pd.read_csv("/content/q15.csv", encoding = "utf-8")
# q16 = pd.read_csv("/content/q16.csv", encoding = "utf-8")
# q17 = pd.read_csv("/content/q17.csv", encoding = "utf-8")
# q18 = pd.read_csv("/content/q18.csv", encoding = "utf-8")
# q19 = pd.read_csv("/content/q19.csv", encoding = "utf-8")
# q20 = pd.read_csv("/content/q20.csv", encoding = "utf-8")
# q21 = pd.read_csv("/content/q21.csv", encoding = "utf-8")
# q22 = pd.read_csv("/content/q22.csv", encoding = "utf-8")
# q23 = pd.read_csv("/content/q23.csv", encoding = "utf-8")
# q24 = pd.read_csv("/content/q24.csv", encoding = "utf-8")
# q25 = pd.read_csv("/content/q25.csv", encoding = "utf-8")
# q26 = pd.read_csv("/content/q26.csv", encoding = "utf-8")
# q27 = pd.read_csv("/content/q27.csv", encoding = "utf-8")
# q28 = pd.read_csv("/content/q28.csv", encoding = "utf-8")
# q29 = pd.read_csv("/content/q29.csv", encoding = "utf-8")
# q30 = pd.read_csv("/content/q20.csv", encoding = "utf-8")
# q31 = pd.read_csv("/content/q31.csv", encoding = "utf-8")
# q32 = pd.read_csv("/content/q32.csv", encoding = "utf-8")
# q33 = pd.read_csv("/content/q33.csv", encoding = "utf-8")
# q34 = pd.read_csv("/content/q34.csv", encoding = "utf-8")
q35 = pd.read_csv("/content/q35.csv", encoding = "utf-8")
q36 = pd.read_csv("/content/q36.csv", encoding = "utf-8")
q37 = pd.read_csv("/content/q37.csv", encoding = "utf-8")
q38 = pd.read_csv("/content/q38.csv", encoding = "utf-8")
q39 = pd.read_csv("/content/q39.csv", encoding = "utf-8")
q40 = pd.read_csv("/content/q40.csv", encoding = "utf-8")
q41 = pd.read_csv("/content/q41.csv", encoding = "utf-8")
q42 = pd.read_csv("/content/q42.csv", encoding = "utf-8")
q43 = pd.read_csv("/content/q43.csv", encoding = "utf-8")
q44 = pd.read_csv("/content/q44.csv", encoding = "utf-8")
q45 = pd.read_csv("/content/q45.csv", encoding = "utf-8")
q46 = pd.read_csv("/content/q46.csv", encoding = "utf-8")
q47 = pd.read_csv("/content/q47.csv", encoding = "utf-8")
q48 = pd.read_csv("/content/q48.csv", encoding = "utf-8")
q49 = pd.read_csv("/content/q49.csv", encoding = "utf-8")
q50 = pd.read_csv("/content/q50.csv", encoding = "utf-8")
q51 = pd.read_csv("/content/q51.csv", encoding = "utf-8")
q52 = pd.read_csv("/content/q52.csv", encoding = "utf-8")
q53 = pd.read_csv("/content/q53.csv", encoding = "utf-8")
q54 = pd.read_csv("/content/q54.csv", encoding = "utf-8")
q55 = pd.read_csv("/content/q55.csv", encoding = "utf-8")
q56 = pd.read_csv("/content/q56.csv", encoding = "utf-8")
q57 = pd.read_csv("/content/q57.csv", encoding = "utf-8")
q58 = pd.read_csv("/content/q58.csv", encoding = "utf-8")
q59 = pd.read_csv("/content/q59.csv", encoding = "utf-8")
q60 = pd.read_csv("/content/q60.csv", encoding = "utf-8")
q61 = pd.read_csv("/content/q61.csv", encoding = "utf-8")
q62 = pd.read_csv("/content/q62.csv", encoding = "utf-8")
q63 = pd.read_csv("/content/q63.csv", encoding = "utf-8")
q64 = pd.read_csv("/content/q64.csv", encoding = "utf-8")

# %%
# 각 데이터 프레임에서 "Unnamed"가 포함된 열 삭제
# q1 = q1[q1.columns.drop(list(q1.filter(regex='Unnamed')))]
# q2 = q2[q2.columns.drop(list(q2.filter(regex='Unnamed')))]
# q3 = q3[q3.columns.drop(list(q3.filter(regex='Unnamed')))]
# q4 = q4[q4.columns.drop(list(q4.filter(regex='Unnamed')))]
# q5 = q5[q5.columns.drop(list(q5.filter(regex='Unnamed')))]
# q6 = q6[q6.columns.drop(list(q6.filter(regex='Unnamed')))]
# q7 = q7[q7.columns.drop(list(q7.filter(regex='Unnamed')))]
# q8 = q8[q8.columns.drop(list(q8.filter(regex='Unnamed')))]
# q9 = q9[q9.columns.drop(list(q9.filter(regex='Unnamed')))]
# q10 = q10[q10.columns.drop(list(q10.filter(regex='Unnamed')))]
# q11 = q11[q11.columns.drop(list(q11.filter(regex='Unnamed')))]
# q12 = q12[q12.columns.drop(list(q12.filter(regex='Unnamed')))]
# q13 = q13[q13.columns.drop(list(q13.filter(regex='Unnamed')))]
# q14 = q14[q14.columns.drop(list(q14.filter(regex='Unnamed')))]
# q15 = q15[q15.columns.drop(list(q15.filter(regex='Unnamed')))]
# q16 = q16[q16.columns.drop(list(q16.filter(regex='Unnamed')))]
# q17 = q17[q17.columns.drop(list(q17.filter(regex='Unnamed')))]
# q18 = q18[q18.columns.drop(list(q18.filter(regex='Unnamed')))]
# q19 = q19[q19.columns.drop(list(q19.filter(regex='Unnamed')))]
# q20 = q20[q20.columns.drop(list(q20.filter(regex='Unnamed')))]
# q21 = q21[q21.columns.drop(list(q21.filter(regex='Unnamed')))]
# q22 = q22[q22.columns.drop(list(q22.filter(regex='Unnamed')))]
# q23 = q23[q23.columns.drop(list(q23.filter(regex='Unnamed')))]
# q24 = q24[q24.columns.drop(list(q24.filter(regex='Unnamed')))]
# q25 = q25[q25.columns.drop(list(q25.filter(regex='Unnamed')))]
# q26 = q26[q26.columns.drop(list(q26.filter(regex='Unnamed')))]
# q27 = q27[q27.columns.drop(list(q27.filter(regex='Unnamed')))]
# q28 = q28[q28.columns.drop(list(q28.filter(regex='Unnamed')))]
# q29 = q29[q29.columns.drop(list(q29.filter(regex='Unnamed')))]
# q30 = q30[q30.columns.drop(list(q30.filter(regex='Unnamed')))]
# q31 = q31[q31.columns.drop(list(q31.filter(regex='Unnamed')))]
# q32 = q32[q32.columns.drop(list(q32.filter(regex='Unnamed')))]
# q33 = q33[q33.columns.drop(list(q33.filter(regex='Unnamed')))]
# q34 = q34[q34.columns.drop(list(q34.filter(regex='Unnamed')))]
q35 = q35[q35.columns.drop(list(q35.filter(regex='Unnamed')))]
q36 = q36[q36.columns.drop(list(q36.filter(regex='Unnamed')))]
q37 = q37[q37.columns.drop(list(q37.filter(regex='Unnamed')))]
q38 = q38[q38.columns.drop(list(q38.filter(regex='Unnamed')))]
q39 = q39[q39.columns.drop(list(q39.filter(regex='Unnamed')))]
q40 = q40[q40.columns.drop(list(q40.filter(regex='Unnamed')))]
q41 = q41[q41.columns.drop(list(q41.filter(regex='Unnamed')))]
q42 = q42[q42.columns.drop(list(q42.filter(regex='Unnamed')))]
q43 = q43[q43.columns.drop(list(q43.filter(regex='Unnamed')))]
q44 = q44[q44.columns.drop(list(q44.filter(regex='Unnamed')))]
q45 = q45[q45.columns.drop(list(q45.filter(regex='Unnamed')))]
q46 = q46[q46.columns.drop(list(q46.filter(regex='Unnamed')))]
q47 = q47[q47.columns.drop(list(q47.filter(regex='Unnamed')))]
q48 = q48[q48.columns.drop(list(q48.filter(regex='Unnamed')))]
q49 = q49[q49.columns.drop(list(q49.filter(regex='Unnamed')))]
q50 = q50[q50.columns.drop(list(q50.filter(regex='Unnamed')))]
q51 = q51[q51.columns.drop(list(q51.filter(regex='Unnamed')))]
q52 = q52[q52.columns.drop(list(q52.filter(regex='Unnamed')))]
q53 = q53[q53.columns.drop(list(q53.filter(regex='Unnamed')))]
q54 = q54[q54.columns.drop(list(q54.filter(regex='Unnamed')))]
q55 = q55[q55.columns.drop(list(q55.filter(regex='Unnamed')))]
q56 = q56[q56.columns.drop(list(q56.filter(regex='Unnamed')))]
q57 = q57[q57.columns.drop(list(q57.filter(regex='Unnamed')))]
q58 = q58[q58.columns.drop(list(q58.filter(regex='Unnamed')))]
q59 = q59[q59.columns.drop(list(q59.filter(regex='Unnamed')))]
q60 = q60[q60.columns.drop(list(q60.filter(regex='Unnamed')))]
q61 = q61[q61.columns.drop(list(q61.filter(regex='Unnamed')))]
q62 = q62[q62.columns.drop(list(q62.filter(regex='Unnamed')))]
q63 = q63[q63.columns.drop(list(q63.filter(regex='Unnamed')))]
q64 = q64[q64.columns.drop(list(q64.filter(regex='Unnamed')))]

# %%
# 질문과 응답만 남기기

# Q1 = q1.iloc[:,[0,1]]
# Q2 = q2.iloc[:,[0,1]]
# Q3 = q3.iloc[:,[0,1]]
# Q4 = q4.iloc[:,[0,1]]
# Q5 = q5.iloc[:,[0,1]]
# Q6 = q6.iloc[:,[0,1]]
# Q7 = q7.iloc[:,[0,1]]
# Q8 = q8.iloc[:,[0,1]]
# Q9 = q9.iloc[:,[0,1]]
# Q10 = q10.iloc[:,[0,1]]
# Q11 = q11.iloc[:,[0,1]]
# Q12 = q12.iloc[:,[0,1]]
# Q13 = q13.iloc[:,[0,1]]
# Q14 = q14.iloc[:,[0,1]]
# Q15 = q15.iloc[:,[0,1]]
# Q16 = q16.iloc[:,[0,1]]
# Q17 = q17.iloc[:,[0,1]]
# Q18 = q18.iloc[:,[0,1]]
# Q19 = q19.iloc[:,[0,1]]
# Q20 = q20.iloc[:,[0,1]]
# Q21 = q21.iloc[:,[0,1]]
# Q22 = q22.iloc[:,[0,1]]
# Q23 = q23.iloc[:,[0,1]]
# Q24 = q24.iloc[:,[0,1]]
# Q25 = q25.iloc[:,[0]]
# Q26 = q26.iloc[:,[0]]
# Q27 = q27.iloc[:,[0]]
# Q28 = q28.iloc[:,[0]]
# Q29 = q29.iloc[:,[0]]
# Q30 = q30.iloc[:,[0]]
# Q31 = q31.iloc[:,[0]]
# Q32 = q32.iloc[:,[0]]
# Q33 = q33.iloc[:,[0]]
# Q34 = q34.iloc[:,[0]]
Q35 = q35.iloc[:,[0]]
Q36 = q36.iloc[:,[0]]
Q37 = q37.iloc[:,[0]]
Q38 = q38.iloc[:,[0]]
Q39 = q39.iloc[:,[0]]
Q40 = q40.iloc[:,[0]]
Q41 = q41.iloc[:,[0]]
Q42 = q42.iloc[:,[0]]
Q43 = q43.iloc[:,[0]]
Q44 = q44.iloc[:,[0]]
Q45 = q45.iloc[:,[0]]
Q46 = q46.iloc[:,[0]]
Q47 = q47.iloc[:,[0]]
Q48 = q48.iloc[:,[0]]
Q49 = q49.iloc[:,[0]]
Q50 = q50.iloc[:,[0]]
Q51 = q51.iloc[:,[0]]
Q52 = q52.iloc[:,[0]]
Q53 = q53.iloc[:,[0]]
Q54 = q54.iloc[:,[0]]
Q55 = q55.iloc[:,[0]]
Q56 = q56.iloc[:,[0]]
Q57 = q57.iloc[:,[0]]
Q58 = q58.iloc[:,[0]]
Q59 = q59.iloc[:,[0]]
Q60 = q60.iloc[:,[0]]
Q61 = q61.iloc[:,[0]]
Q62 = q62.iloc[:,[0]]
Q63 = q63.iloc[:,[0]]
Q64 = q64.iloc[:,[0]]

# %%
# 인덱스 설정
# Q1 = Q1.set_index('코드')
# Q2 = Q2.set_index('코드')
# Q3 = Q3.set_index('코드')
# Q4 = Q4.set_index('코드')
# Q5 = Q5.set_index('코드')
# Q6 = Q6.set_index('코드')
# Q7 = Q7.set_index('코드')
# Q8 = Q8.set_index('코드')
# Q9 = Q9.set_index('코드')
# Q10 = Q10.set_index('코드')
# Q11 = Q11.set_index('코드')
# Q12 = Q12.set_index('코드')
# Q13 = Q13.set_index('코드')
# Q14 = Q14.set_index('코드')
# Q15 = Q15.set_index('코드')
# Q16 = Q16.set_index('코드')
# Q17 = Q17.set_index('코드')
# Q18 = Q18.set_index('코드')
# Q19 = Q19.set_index('코드')
# Q20 = Q20.set_index('코드')
# Q21 = Q21.set_index('코드')
# Q22 = Q22.set_index('코드')
# Q23 = Q23.set_index('코드')
# Q24 = Q24.set_index('코드')
# # Q25 = Q25.set_index('코드')
# # Q26 = Q26.set_index('코드')
# # Q27 = Q27.set_index('코드')
# # Q28 = Q28.set_index('코드')
# # Q29 = Q29.set_index('코드')
# # Q30 = Q30.set_index('코드')
# # Q31 = Q31.set_index('코드')
# # Q32 = Q32.set_index('코드')
# # Q33 = Q33.set_index('코드')
# # Q34 = Q34.set_index('코드')
# # Q35 = Q35.set_index('코드')
# # Q36 = Q36.set_index('코드')
# # Q37 = Q37.set_index('코드')
# # Q38 = Q38.set_index('코드')
# # Q39 = Q39.set_index('코드')
# # Q40 = Q40.set_index('코드')
# # Q41 = Q41.set_index('코드')
# # Q42 = Q42.set_index('코드')
# # Q43 = Q43.set_index('코드')
# # Q44 = Q44.set_index('코드')
# # Q45 = Q45.set_index('코드')
# # Q46 = Q46.set_index('코드')
# # Q47 = Q47.set_index('코드')
# # Q48 = Q48.set_index('코드')
# # Q49 = Q49.set_index('코드')
# # Q50 = Q50.set_index('코드')
# # Q51 = Q51.set_index('코드')
# # Q52 = Q52.set_index('코드')
# # Q53 = Q53.set_index('코드')
# # Q54 = Q54.set_index('코드')
# # Q55 = Q55.set_index('코드')
# # Q56 = Q56.set_index('코드')
# # Q57 = Q57.set_index('코드')
# # Q58 = Q58.set_index('코드')
# # Q59 = Q59.set_index('코드')
# # Q60 = Q60.set_index('코드')
# # Q61 = Q61.set_index('코드')
# # Q62 = Q62.set_index('코드')
# # Q63 = Q63.set_index('코드')
# # Q64 = Q64.set_index('코드')

# %%
# 결측치 제거
# Q1 = Q1.dropna(axis=0)
# Q2 = Q2.dropna(axis=0)
# Q3 = Q3.dropna(axis=0)
# Q4 = Q4.dropna(axis=0)
# Q5 = Q5.dropna(axis=0)
# Q6 = Q6.dropna(axis=0)
# Q7 = Q7.dropna(axis=0)
# Q8 = Q8.dropna(axis=0)
# Q9 = Q9.dropna(axis=0)
# Q10 = Q10.dropna(axis=0)
# Q11 = Q11.dropna(axis=0)
# Q12 = Q12.dropna(axis=0)
# Q13 = Q13.dropna(axis=0)
# Q14 = Q14.dropna(axis=0)
# Q15 = Q15.dropna(axis=0)
# Q16 = Q16.dropna(axis=0)
# Q17 = Q17.dropna(axis=0)
# Q18 = Q18.dropna(axis=0)
# Q19 = Q19.dropna(axis=0)
# Q20 = Q20.dropna(axis=0)
# Q21 = Q21.dropna(axis=0)
# Q22 = Q22.dropna(axis=0)
# Q23 = Q23.dropna(axis=0)
# Q24 = Q24.dropna(axis=0)
# Q25 = Q25.dropna(axis=0)
# Q26 = Q26.dropna(axis=0)
# Q27 = Q27.dropna(axis=0)
# Q28 = Q28.dropna(axis=0)
# Q29 = Q29.dropna(axis=0)
# Q30 = Q30.dropna(axis=0)
# Q31 = Q31.dropna(axis=0)
# Q32 = Q32.dropna(axis=0)
# Q33 = Q33.dropna(axis=0)
# Q34 = Q34.dropna(axis=0)
Q35 = Q35.dropna(axis=0)
Q36 = Q36.dropna(axis=0)
Q37 = Q37.dropna(axis=0)
Q38 = Q38.dropna(axis=0)
Q39 = Q39.dropna(axis=0)
Q40 = Q40.dropna(axis=0)
Q41 = Q41.dropna(axis=0)
Q42 = Q42.dropna(axis=0)
Q43 = Q43.dropna(axis=0)
Q44 = Q44.dropna(axis=0)
Q45 = Q45.dropna(axis=0)
Q46 = Q46.dropna(axis=0)
Q47 = Q47.dropna(axis=0)
Q48 = Q48.dropna(axis=0)
Q49 = Q49.dropna(axis=0)
Q50 = Q50.dropna(axis=0)
Q51 = Q51.dropna(axis=0)
Q52 = Q52.dropna(axis=0)
Q53 = Q53.dropna(axis=0)
Q54 = Q54.dropna(axis=0)
Q55 = Q55.dropna(axis=0)
Q56 = Q56.dropna(axis=0)
Q57 = Q57.dropna(axis=0)
Q58 = Q58.dropna(axis=0)
Q59 = Q59.dropna(axis=0)
Q60 = Q60.dropna(axis=0)
Q61 = Q61.dropna(axis=0)
Q62 = Q62.dropna(axis=0)
Q63 = Q63.dropna(axis=0)
Q64 = Q64.dropna(axis=0)

# %%
# Q1.to_csv("Q1.csv",index = False)
# Q2.to_csv("Q2.csv",index = False)
# Q3.to_csv("Q3.csv",index = False)
# Q4.to_csv("Q4.csv",index = False)
# Q5.to_csv("Q5.csv",index = False)
# Q6.to_csv("Q6.csv",index = False)
# Q7.to_csv("Q7.csv",index = False)
# Q8.to_csv("Q8.csv",index = False)
# Q9.to_csv("Q9.csv",index = False)
# Q10.to_csv("Q10.csv",index = False)
# Q11.to_csv("Q11.csv",index = False)
# Q12.to_csv("Q12.csv",index = False)
# Q13.to_csv("Q13.csv",index = False)
# Q14.to_csv("Q14.csv",index = False)
# Q15.to_csv("Q15.csv",index = False)
# Q16.to_csv("Q16.csv",index = False)
# Q17.to_csv("Q17.csv",index = False)
# Q18.to_csv("Q18.csv",index = False)
# Q19.to_csv("Q19.csv",index = False)
# Q20.to_csv("Q20.csv",index = False)
# Q21.to_csv("Q21.csv",index = False)
# Q22.to_csv("Q22.csv",index = False)
# Q23.to_csv("Q23.csv",index = False)
# Q24.to_csv("Q24.csv",index = False)
# Q25.to_csv("Q25.csv",index = False)
# Q26.to_csv("Q26.csv",index = False)
# Q27.to_csv("Q27.csv",index = False)
# Q28.to_csv("Q28.csv",index = False)
# Q29.to_csv("Q29.csv",index = False)
# Q30.to_csv("Q30.csv",index = False)
# Q31.to_csv("Q31.csv",index = False)
# Q32.to_csv("Q32.csv",index = False)
# Q33.to_csv("Q33.csv",index = False)
# Q34.to_csv("Q34.csv",index = False)
Q35.to_csv("Q35.csv",index = False)
Q36.to_csv("Q36.csv",index = False)
Q37.to_csv("Q37.csv",index = False)
Q38.to_csv("Q38.csv",index = False)
Q39.to_csv("Q39.csv",index = False)
Q40.to_csv("Q40.csv",index = False)
Q41.to_csv("Q41.csv",index = False)
Q42.to_csv("Q42.csv",index = False)
Q43.to_csv("Q43.csv",index = False)
Q44.to_csv("Q44.csv",index = False)
Q45.to_csv("Q45.csv",index = False)
Q46.to_csv("Q46.csv",index = False)
Q47.to_csv("Q47.csv",index = False)
Q48.to_csv("Q48.csv",index = False)
Q49.to_csv("Q49.csv",index = False)
Q50.to_csv("Q50.csv",index = False)
Q51.to_csv("Q51.csv",index = False)
Q52.to_csv("Q52.csv",index = False)
Q53.to_csv("Q53.csv",index = False)
Q54.to_csv("Q54.csv",index = False)
Q55.to_csv("Q55.csv",index = False)
Q56.to_csv("Q56.csv",index = False)
Q57.to_csv("Q57.csv",index = False)
Q58.to_csv("Q58.csv",index = False)
Q59.to_csv("Q59.csv",index = False)
Q60.to_csv("Q60.csv",index = False)
Q61.to_csv("Q61.csv",index = False)
Q62.to_csv("Q62.csv",index = False)
Q63.to_csv("Q63.csv",index = False)
Q64.to_csv("Q64.csv",index = False)

# %%
# !pip install JPype1

# %%
# !pip install aspose-cells

# %%
  # csv파일을 txt파일로 변환
  
  import  jpype     
  import  asposecells     
  jpype.startJVM() 
  from asposecells.api import Workbook
  
  # # load CSV file
  # workbook = Workbook("/content/Q1.csv");
  
  # # save as TXT
  # workbook.save("Q1.txt");
  
  # # jpype.shutdownJVM()

      # load CSV file
  workbook = Workbook("/content/Q35.csv");
  
  # save as TXT
  workbook.save("Q35.txt");
  
 # jpype.shutdownJVM()

# %%
  # # Q1-10

  # # load CSV file
  # workbook = Workbook("/content/Q2.csv");
  
  # # save as TXT
  # workbook.save("Q2.txt");
  
  # # jpype.shutdownJVM()



  #   # load CSV file
  # workbook = Workbook("/content/Q3.csv");
  
  # # save as TXT
  # workbook.save("Q3.txt");
  
  # # jpype.shutdownJVM()

  # # csv파일을 txt파일로 변환
  

  #   # load CSV file
  # workbook = Workbook("/content/Q4.csv");
  
  # # save as TXT
  # workbook.save("Q4.txt");
  
  # # jpype.shutdownJVM()



  #   # load CSV file
  # workbook = Workbook("/content/Q5.csv");
  
  # # save as TXT
  # workbook.save("Q5.txt");
  
  # # jpype.shutdownJVM()



  #   # load CSV file
  # workbook = Workbook("/content/Q6.csv");
  
  # # save as TXT
  # workbook.save("Q6.txt");
  
  # # jpype.shutdownJVM()




  #   # load CSV file
  # workbook = Workbook("/content/Q7.csv");
  
  # # save as TXT
  # workbook.save("Q7.txt");
  
  # # jpype.shutdownJVM()


  # # csv파일을 txt파일로 변환


  #   # load CSV file
  # workbook = Workbook("/content/Q8.csv");
  
  # # save as TXT
  # workbook.save("Q8.txt");
  
  # # jpype.shutdownJVM()



  #  # load CSV file
  # workbook = Workbook("/content/Q9.csv");
  
  # # save as TXT
  # workbook.save("Q9.txt");
  
  # # jpype.shutdownJVM()


  # # load CSV file
  # workbook = Workbook("/content/Q10.csv");
  
  # # save as TXT
  # workbook.save("Q10.txt");
  
  # # jpype.shutdownJVM()

# %%
#   # Q11-20
  
#   # load CSV file
#   workbook = Workbook("/content/Q11.csv");
  
#   # save as TXT
#   workbook.save("Q11.txt");
  
#   #jpype.shutdownJVM()

#   # load CSV file
#   workbook = Workbook("/content/Q12.csv");
  
#   # save as TXT
#   workbook.save("Q12.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q13.csv");
  
#   # save as TXT
#   workbook.save("Q13.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q14.csv");
  
#   # save as TXT
#   workbook.save("Q14.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q15.csv");
  
#   # save as TXT
#   workbook.save("Q15.txt");
  
# ##  jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q16.csv");
  
#   # save as TXT
#   workbook.save("Q16.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q17.csv");
  
#   # save as TXT
#   workbook.save("Q17.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q18.csv");
  
#   # save as TXT
#   workbook.save("Q18.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q19.csv");
  
#   # save as TXT
#   workbook.save("Q19.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q20.csv");
  
#   # save as TXT
#   workbook.save("Q20.txt");
  
#  # jpype.shutdownJVM()

# %%
#   # Q21-30

#   # load CSV file
#   workbook = Workbook("/content/Q21.csv");
  
#   # save as TXT
#   workbook.save("Q21.txt");
  
#   #jpype.shutdownJVM()

#   # load CSV file
#   workbook = Workbook("/content/Q22.csv");
  
#   # save as TXT
#   workbook.save("Q22.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q23.csv");
  
#   # save as TXT
#   workbook.save("Q23.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q24.csv");
  
#   # save as TXT
#   workbook.save("Q24.txt");
  
# #  jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q25.csv");
  
#   # save as TXT
#   workbook.save("Q25.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q26.csv");
  
#   # save as TXT
#   workbook.save("Q26.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q27.csv");
  
#   # save as TXT
#   workbook.save("Q27.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q28.csv");
  
#   # save as TXT
#   workbook.save("Q28.txt");
  
#  # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q29.csv");
  
#   # save as TXT
#   workbook.save("Q29.txt");
  
#  # jpype.shutdownJVM()
#     # load CSV file
#   workbook = Workbook("/content/Q30.csv");
  
#   # save as TXT
#   workbook.save("Q30.txt");
  
#  # jpype.shutdownJVM()

# %%
#   # Q31-40
  
#   # load CSV file
#   workbook = Workbook("/content/Q31.csv");
  
#   # save as TXT
#   workbook.save("Q31.txt");
  
#  # jpype.shutdownJVM()

#   # load CSV file
#   workbook = Workbook("/content/Q32.csv");
  
#   # save as TXT
#   workbook.save("Q32.txt");
  
#   #jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q33.csv");
  
#   # save as TXT
#   workbook.save("Q33.txt");
  
#   #jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q34.csv");
  
#   # save as TXT
#   workbook.save("Q34.txt");
  
 # jpype.shutdownJVM()

#     # load CSV file
#   workbook = Workbook("/content/Q35.csv");
  
#   # save as TXT
#   workbook.save("Q35.txt");
  
#  # jpype.shutdownJVM()

  # load CSV file
  workbook = Workbook("/content/Q36.csv");
  
  # save as TXT
  workbook.save("Q36.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q37.csv");
  
  # save as TXT
  workbook.save("Q37.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q38.csv");
  
  # save as TXT
  workbook.save("Q38.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q39.csv");
  
  # save as TXT
  workbook.save("Q39.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q40.csv");
  
  # save as TXT
  workbook.save("Q40.txt");
  
 # jpype.shutdownJVM()

# %%
# load CSV file
workbook = Workbook("/content/Q36.csv");
  
# save as TXT
workbook.save("Q36.txt");
 
# jpype.shutdownJVM()

# load CSV file
workbook = Workbook("/content/Q37.csv");
  
# save as TXT
workbook.save("Q37.txt");
  
# jpype.shutdownJVM()

# load CSV file
workbook = Workbook("/content/Q38.csv");
  
# save as TXT
workbook.save("Q38.txt");
  
# jpype.shutdownJVM()

# load CSV file
workbook = Workbook("/content/Q39.csv");
  
# save as TXT
workbook.save("Q39.txt");
  
#jpype.shutdownJVM()

# load CSV file
workbook = Workbook("/content/Q40.csv");
  
# save as TXT
workbook.save("Q40.txt");
  
# jpype.shutdownJVM()

# %%
  # Q41-50
  
  # load CSV file
  workbook = Workbook("/content/Q41.csv");
  
  # save as TXT
  workbook.save("Q41.txt");
  
 # jpype.shutdownJVM()

  # load CSV file
  workbook = Workbook("/content/Q42.csv");
  
  # save as TXT
  workbook.save("Q42.txt");
  
#  jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q43.csv");
  
  # save as TXT
  workbook.save("Q43.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q44.csv");
  
  # save as TXT
  workbook.save("Q44.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q45.csv");
  
  # save as TXT
  workbook.save("Q45.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q46.csv");
  
  # save as TXT
  workbook.save("Q46.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q47.csv");
  
  # save as TXT
  workbook.save("Q47.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q48.csv");
  
  # save as TXT
  workbook.save("Q48.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q49.csv");
  
  # save as TXT
  workbook.save("Q49.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q50.csv");
  
  # save as TXT
  workbook.save("Q50.txt");
  
  #jpype.shutdownJVM()

# %%
  # Q51-60
 
  # load CSV file
  workbook = Workbook("/content/Q51.csv");
  
  # save as TXT
  workbook.save("Q51.txt");
  
#  jpype.shutdownJVM()

  # load CSV file
  workbook = Workbook("/content/Q52.csv");
  
  # save as TXT
  workbook.save("Q52.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q53.csv");
  
  # save as TXT
  workbook.save("Q53.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q54.csv");
  
  # save as TXT
  workbook.save("Q54.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q55.csv");
  
  # save as TXT
  workbook.save("Q55.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q56.csv");
  
  # save as TXT
  workbook.save("Q56.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q57.csv");
  
  # save as TXT
  workbook.save("Q57.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q58.csv");
  
  # save as TXT
  workbook.save("Q58.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q59.csv");
  
  # save as TXT
  workbook.save("Q59.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q60.csv");
  
  # save as TXT
  workbook.save("Q60.txt");
  
  #jpype.shutdownJVM()

# %%
  # Q61-64
  
  # load CSV file
  workbook = Workbook("/content/Q61.csv");
  
  # save as TXT
  workbook.save("Q61.txt");
  
 # jpype.shutdownJVM()

  # load CSV file
  workbook = Workbook("/content/Q62.csv");
  
  # save as TXT
  workbook.save("Q62.txt");
  
 # jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q63.csv");
  
  # save as TXT
  workbook.save("Q63.txt");
  
  #jpype.shutdownJVM()

    # load CSV file
  workbook = Workbook("/content/Q64.csv");
  
  # save as TXT
  workbook.save("Q64.txt");
  
 # jpype.shutdownJVM()

# %%
jpype.shutdownJVM()

# %% [markdown]
# # API로 번역하기
# - 주석처리 한 셀은 오류발생
# - 현재 실행 가능 셀은 문장을 일일히 작성해야함

# %%
import requests
 
 
request_url = "https://openapi.naver.com/v1/papago/n2mt"
text = "파이썬으로 번역하는 거 왜 저만 못하는걸까요?"
 
headers = {"X-Naver-Client-Id": "zaBs1yQcvxLf7GgV0EDb", "X-Naver-Client-Secret": "5rAA2QZNd7"}
params = {"source": "ko", "target": "en", "text": text}
response = requests.post(request_url, headers=headers, data=params)
 
result = response.json()
 
print(result)

# %%
# from pypapago import Translator

# # 번역할 파일명
# fileName = './Q1.txt'

# # 사용할 전역변수
# templist = []
# afterTranslate = []

# # 객체 할당
# translator = Translator()

# # 파일 읽기모드, 줄을 읽고 \n를 제거하여 번역하기
# with open(fileName, 'r') as f:
#     lines = f.readlines()
#     for line in lines:
#         # '\n'엔터키''가 있을 때 교체하여 추가, 그 외 그냥 추가
#         if '\n' in line:
#             line = line.replace('\n', '')
#             templist.append(line)
#         else:
#             templist.append(line)

#         # 문자열이 비어있는 리스트는 삭제
#         try:
#             templist.remove('')
#         except:
#             pass  

# # 리스트 내 영어 자료들 번역하기
# for i in range(len(templist)):
#     result = translator.translate(templist[i], source='en', target='ko', verbose=False)
#     afterTranslate.append(result)

# # 초기 리스트값, 바꾼 후, 번역 후(출력테스트)
# print(lines)
# print(templist)
# print(afterTranslate)

# # 번역 후 text파일 만듦.
# with open(fileName + 'Q1_translated.txt', 'w') as f:
#     for i in range(len(afterTranslate)):
#         data = afterTranslate[i] + '\n'
#         f.write(data)

# %%
# from requests import Request
# from requests import Session

# f = open('Q1.txt' ,'r')
# text = f.read()
# f.close()

# s = Session()

# client_id = "zaBs1yQcvxLf7GgV0EDb" # 개발자센터에서 발급받은 Client ID 값
# client_secret = "5rAA2QZNd7" # 개발자센터에서 발급받은 Client Secret 값

# payload = {
#     'source': 'ko',
#     'target': 'en',
#     'text': text,
# }

# url = "https://openapi.naver.com/v1/papago/n2mt"
# request = urllib.request.Request(url)
# request.add_header("X-Naver-Client-Id",client_id)
# request.add_header("X-Naver-Client-Secret",client_secret)
# prepped = req.prepare()

# res = s.send(prepped)

# print(res.json())

# result = res.json()['message']['result']['translatedText']

# print(result)

# %%
### 새로짠 코드 인데 "{'errorMessage': 'NID AUTH Result Invalid (1000) : Authentication failed. (인증에 실패했습니다.)', 'errorCode': '024'}" 이런 오류 메세지 발생

# from requests import Request
# from requests import Session

# f = open('Q1.txt' ,'r')
# text = f.read()
# f.close()

# s = Session()

# client_id = "zaBs1yQcvxLf7GgV0EDb" # 개발자센터에서 발급받은 Client ID 값
# client_secret = "5rAA2QZNd7" # 개발자센터에서 발급받은 Client Secret 값

# payload = {
#     'source': 'ko',
#     'target': 'en',
#     'text': text,
# }

# url = "https://openapi.naver.com/v1/papago/n2mt"
# headers = {"X-Naver-Client-Id": "client_id", "X-Naver-Client-Secret": "client_secret"}
# params = {"source": "en", "target": "ko", "text": text}
# response = requests.post(url, headers=headers, data=params)
 
# result = response.json()
 
# print(result)
